# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('heart_2020_cleaned.csv')

# %%
data
# Out:
#        HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0                No  16.60     Yes              No     No             3.0
# 1                No  20.34      No              No    Yes             0.0
# 2                No  26.58     Yes              No     No            20.0
# 3                No  24.21      No              No     No             0.0
# 4                No  23.71      No              No     No            28.0
# ...             ...    ...     ...             ...    ...             ...
# 319790          Yes  27.41     Yes              No     No             7.0
# 319791           No  29.84     Yes              No     No             0.0
# 319792           No  24.24      No              No     No             0.0
# 319793           No  32.81      No              No     No             0.0
# 319794           No  46.56      No              No     No             0.0
#
#         MentalHealth DiffWalking     Sex  AgeCategory      Race Diabetic  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 319795 entries, 0 to 319794
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   HeartDisease      319795 non-null  object
#  1   BMI               319795 non-null  float64
#  2   Smoking           319795 non-null  object
#  3   AlcoholDrinking   319795 non-null  object
#  4   Stroke            319795 non-null  object
#  5   PhysicalHealth    319795 non-null  float64
#  6   MentalHealth      319795 non-null  float64
#  7   DiffWalking       319795 non-null  object
#  8   Sex               319795 non-null  object
#  9   AgeCategory       319795 non-null  object
#  10  Race              319795 non-null  object
#  11  Diabetic          319795 non-null  object
#  12  PhysicalActivity  319795 non-null  object
#  13  GenHealth         319795 non-null  object
#  14  SleepTime         319795 non-null  float64
# ...

# %% [markdown]
# #### Heart Disease: Respondents that have ever reported having coronary heart disease (CHD) or myocardial infarction (MI)

# %%
data['HeartDisease'].value_counts()
# Out:
# No     292422
# Yes     27373
# Name: HeartDisease, dtype: int64

# %%
import seaborn as sns

# %% [markdown]
# #### BMI: Body Mass Index

# %%
sns.histplot(data['BMI'],kde=True)

print("min BMI:",data['BMI'].min())
print("max BMI:",data['BMI'].max())
print("mean BMI:",data['BMI'].mean())
print("median BMI:",data['BMI'].median())
print("min BMI:",data['BMI'].std())
# Out:
# min BMI: 12.02
# max BMI: 94.85
# mean BMI: 28.325398520927465
# median BMI: 27.34
# min BMI: 6.356100200471519

# %% [markdown]
# #### Smoking:Have you smoked at least 100 cigarettes in your entire life? [Note: 5 packs = 100 cigarettes]

# %%
data['Smoking'].value_counts()
# Out:
# No     187887
# Yes    131908
# Name: Smoking, dtype: int64

# %% [markdown]
# #### Alcohol Drinking: Heavy drinkers (adult men having more than 14 drinks per week and adult women having more than 7 drinks per week

# %%
data['AlcoholDrinking'].value_counts()
# Out:
# No     298018
# Yes     21777
# Name: AlcoholDrinking, dtype: int64

# %% [markdown]
# #### Stroke: (Ever told) (you had) a stroke?

# %%
data['Stroke'].value_counts()
# Out:
# No     307726
# Yes     12069
# Name: Stroke, dtype: int64

# %% [markdown]
# #### Physical Health:Now thinking about your physical health, which includes physical illness and injury, for how many days during the past 30 days your physical health was not good?

# %%
data['PhysicalHealth']
# Out:
# 0          3.0
# 1          0.0
# 2         20.0
# 3          0.0
# 4         28.0
#           ...
# 319790     7.0
# 319791     0.0
# 319792     0.0
# 319793     0.0
# 319794     0.0
# Name: PhysicalHealth, Length: 319795, dtype: float64

# %%
sns.histplot(data['PhysicalHealth'],binwidth=2,kde=True)

print("min physical health:",data['PhysicalHealth'].min())
print("max physical health:",data['PhysicalHealth'].max())
print("mean physical health:",data['PhysicalHealth'].mean())
print("median physical health:",data['PhysicalHealth'].median())
print("min physical health:",data['PhysicalHealth'].std())
# Out:
# min physical health: 0.0
# max physical health: 30.0
# mean physical health: 3.3717100017198516
# median physical health: 0.0
# min physical health: 7.95085018257456

# %% [markdown]
# #### Mental Health: Thinking about your mental health, for how many days during the past 30 days was your mental health not good?

# %%
data['MentalHealth']
# Out:
# 0         30.0
# 1          0.0
# 2         30.0
# 3          0.0
# 4          0.0
#           ...
# 319790     0.0
# 319791     0.0
# 319792     0.0
# 319793     0.0
# 319794     0.0
# Name: MentalHealth, Length: 319795, dtype: float64

# %%
sns.histplot(data['MentalHealth'],binwidth=2,kde=True)

print("min mental health:",data['MentalHealth'].min())
print("max mental health:",data['MentalHealth'].max())
print("mean mental health:",data['MentalHealth'].mean())
print("median mental health:",data['MentalHealth'].median())
print("min mental health:",data['MentalHealth'].std())
# Out:
# min mental health: 0.0
# max mental health: 30.0
# mean mental health: 3.898366140808956
# median mental health: 0.0
# min mental health: 7.955235218946832

# %% [markdown]
# #### DiffWalking:Do you have serious difficulty walking or climbing stairs?

# %%
data['DiffWalking'].value_counts()
# Out:
# No     275385
# Yes     44410
# Name: DiffWalking, dtype: int64

# %% [markdown]
# #### Sex:Are you male or female?

# %%
data['Sex'].value_counts()
# Out:
# Female    167805
# Male      151990
# Name: Sex, dtype: int64

# %% [markdown]
# #### AgeCategory:Fourteen-level age category

# %%
data['AgeCategory'].value_counts()
# Out:
# 65-69          34151
# 60-64          33686
# 70-74          31065
# 55-59          29757
# 50-54          25382
# 80 or older    24153
# 45-49          21791
# 75-79          21482
# 18-24          21064
# 40-44          21006
# 35-39          20550
# 30-34          18753
# 25-29          16955
# Name: AgeCategory, dtype: int64

# %% [markdown]
# ##### Age Categories:
#     1. 18-24
#     2. 25-29
#     3. 30-34
#     4. 35-39
#     5. 40-44
#     6. 45-49
#     7. 50-54
#     8. 55-59
#     9. 60-64
#     10. 65-69
#     11. 70-74
#     12. 75-79
#     13. 80 or older

# %% [markdown]
# #### Race

# %%
data['Race'].value_counts()
# Out:
# White                             245212
# Hispanic                           27446
# Black                              22939
# Other                              10928
# Asian                               8068
# American Indian/Alaskan Native      5202
# Name: Race, dtype: int64

# %% [markdown]
# #### Diabetic

# %%
data['Diabetic'].value_counts()
# Out:
# No                         269653
# Yes                         40802
# No, borderline diabetes      6781
# Yes (during pregnancy)       2559
# Name: Diabetic, dtype: int64

# %% [markdown]
# #### Physical Activity

# %%
data['PhysicalActivity'].value_counts()
# Out:
# Yes    247957
# No      71838
# Name: PhysicalActivity, dtype: int64

# %% [markdown]
# #### General Health

# %%
data['GenHealth'].value_counts()
# Out:
# Very good    113858
# Good          93129
# Excellent     66842
# Fair          34677
# Poor          11289
# Name: GenHealth, dtype: int64

# %% [markdown]
# #### Sleep Time

# %%
sleep_time=data['SleepTime'].value_counts()

# %%
sns.histplot(data['SleepTime'],binwidth=1,kde=True)

print("min sleep time:",data['SleepTime'].min())
print("max sleep time:",data['SleepTime'].max())
print("mean sleep time:",data['SleepTime'].mean())
print("median sleep time:",data['SleepTime'].median())
print("min sleep time:",data['SleepTime'].std())
# Out:
# min sleep time: 1.0
# max sleep time: 24.0
# mean sleep time: 7.097074688472302
# median sleep time: 7.0
# min sleep time: 1.4360070609668765

# %% [markdown]
# #### Asthma

# %%
data['Asthma'].value_counts()
# Out:
# No     276923
# Yes     42872
# Name: Asthma, dtype: int64

# %% [markdown]
# #### Kidney Disease

# %%
data['KidneyDisease'].value_counts()
# Out:
# No     308016
# Yes     11779
# Name: KidneyDisease, dtype: int64

# %% [markdown]
# #### Skin Cancer

# %%
data['SkinCancer'].value_counts()
# Out:
# No     289976
# Yes     29819
# Name: SkinCancer, dtype: int64

# %% [markdown]
# ### Analysis of Stroke

# %% [markdown]
# ##### How does Heart Disease affect Stroke?

# %%
data[['HeartDisease','Stroke']].value_counts()
# Out:
# HeartDisease  Stroke
# No            No        284742
# Yes           No         22984
# No            Yes         7680
# Yes           Yes         4389
# dtype: int64

# %%
plt.title('Stroke among people having heart disease')
plt.pie([22984,4389],labels=['Didn\'t get stroke','Got Stroke'],autopct='%.2f')
plt.show()

# %%
plt.title('Stroke among people not having heart disease')
plt.pie([284742,7680],labels=['Didn\'t get stroke','Got Stroke'],autopct='%.2f')
plt.show()

# %%
data.replace('Yes',1,inplace=True)
data.replace('No',0,inplace=True)

# %% [markdown]
# ##### How does BMI affect stroke

# %%
having_hd=data[data['Stroke']==1]
not_having_hd=data[data['Stroke']==0]

# %% [markdown]
# BMI Distribution among those who got a stroke

# %%
not_having_hd['BMI']
# Out:
# 0         16.60
# 2         26.58
# 3         24.21
# 4         23.71
# 5         28.87
#           ...
# 319790    27.41
# 319791    29.84
# 319792    24.24
# 319793    32.81
# 319794    46.56
# Name: BMI, Length: 307726, dtype: float64

# %%
having_hd['BMI']
# Out:
# 1         20.34
# 35        32.98
# 40        22.60
# 49        27.46
# 59        27.20
#           ...
# 319588    30.56
# 319619    39.31
# 319620    27.64
# 319740    26.07
# 319765    38.45
# Name: BMI, Length: 12069, dtype: float64

# %%
sns.histplot(having_hd['BMI'],kde=True)

print("Min BMI:",having_hd['BMI'].min())
print("Max BMI:",having_hd['BMI'].max())
print("Mean BMI:",having_hd['BMI'].mean())
print("Median BMI:",having_hd['BMI'].median())
print("Mode BMI:",having_hd['BMI'].mode())
print("Std BMI:",having_hd['BMI'].std())
# Out:
# Min BMI: 12.48
# Max BMI: 84.44
# Mean BMI: 28.958727317921948
# Median BMI: 28.06
# Mode BMI: 0    26.63
# Name: BMI, dtype: float64
# Std BMI: 6.684328340521937

# %% [markdown]
# BMI Distribution among those not having stroke

# %%
sns.histplot(not_having_hd['BMI'],kde=True)

print("Min BMI:",not_having_hd['BMI'].min())
print("Max BMI:",not_having_hd['BMI'].max())
print("Mean BMI:",not_having_hd['BMI'].mean())
print("Median BMI:",not_having_hd['BMI'].median())
print("Mode BMI:",not_having_hd['BMI'].mode())
print("Std BMI:",not_having_hd['BMI'].std())
# Out:
# Min BMI: 12.02
# Max BMI: 94.85
# Mean BMI: 28.300559393746376
# Median BMI: 27.32
# Mode BMI: 0    26.63
# Name: BMI, dtype: float64
# Std BMI: 6.341603534498051

# %% [markdown]
# ##### How does smoking affect Stroke?

# %%
data[['Smoking','Stroke']].value_counts()
# Out:
# Smoking  Stroke
# 0        0         182633
# 1        0         125093
#          1           6815
# 0        1           5254
# dtype: int64

# %% [markdown]
# Distribution of stroke among people who smoke

# %%
plt.title('Stroke among people who smoke')
plt.pie([125093,6815],labels=['Doesn\'t Smoke','Smokes'],autopct='%.2f')
plt.show()

# %% [markdown]
# Distribution of Stroke among people who doesn't smoke

# %%
plt.title('Stroke among people who don\'t smoke')
plt.pie([182633,5244],labels=['Doesn\'t Smoke','Smokes'],autopct='%.2f')
plt.show()

# %% [markdown]
# chances of getting a stroke is 2.36 times more in people who smoke than who do not

# %% [markdown]
# ##### How does physical health affect stroke

# %%
stroke_y=data[data['Stroke']==1]
stroke_n=data[data['Stroke']==0]

# %% [markdown]
# Distribution of Physical Health among people who got stroke

# %%
sns.histplot(stroke_y['PhysicalHealth'],kde=True)

plt.title('Distribution of Physical Health among people who got stroke')
print("Min :",stroke_y['PhysicalHealth'].min())
print("Max :",stroke_y['PhysicalHealth'].max())
print("Mean :",stroke_y['PhysicalHealth'].mean())
print("Median :",stroke_y['PhysicalHealth'].median())
print("Mode :",stroke_y['PhysicalHealth'].mode())
print("Std :",stroke_y['PhysicalHealth'].std())
# Out:
# Min : 0.0
# Max : 30.0
# Mean : 8.87248322147651
# Median : 1.0
# Mode : 0    0.0
# Name: PhysicalHealth, dtype: float64
# Std : 11.90056844470327

# %% [markdown]
# Distribution of Physical Health who didnot get a stroke

# %%
sns.histplot(stroke_n['PhysicalHealth'],kde=True,binwidth=1)

plt.title('Distribution of Physical Health among people who didnot get stroke')
print("Min :",stroke_n['PhysicalHealth'].min())
print("Max :",stroke_n['PhysicalHealth'].max())
print("Mean :",stroke_n['PhysicalHealth'].mean())
print("Median :",stroke_n['PhysicalHealth'].median())
print("Mode :",stroke_n['PhysicalHealth'].mode())
print("Std :",stroke_n['PhysicalHealth'].std())
# Out:
# Min : 0.0
# Max : 30.0
# Mean : 3.1559699212936185
# Median : 0.0
# Mode : 0    0.0
# Name: PhysicalHealth, dtype: float64
# Std : 7.675157636170023

# %% [markdown]
# ##### How does mental health afftect stroke

# %%
sns.histplot(stroke_y['MentalHealth'],kde=True)

plt.title('Distribution of Mental Health among people who got stroke')
print("Min :",stroke_y['MentalHealth'].min())
print("Max :",stroke_y['MentalHealth'].max())
print("Mean :",stroke_y['MentalHealth'].mean())
print("Median :",stroke_y['MentalHealth'].median())
print("Mode :",stroke_y['MentalHealth'].mode())
print("Std :",stroke_y['MentalHealth'].std())
# Out:
# Min : 0.0
# Max : 30.0
# Mean : 5.764934957328693
# Median : 0.0
# Mode : 0    0.0
# Name: MentalHealth, dtype: float64
# Std : 9.979869199234766

# %%
sns.histplot(stroke_n['MentalHealth'],kde=True,binwidth=1)

plt.title('Distribution of Mental Health among people who didnot get stroke')
print("Min :",stroke_n['MentalHealth'].min())
print("Max :",stroke_n['MentalHealth'].max())
print("Mean :",stroke_n['MentalHealth'].mean())
print("Median :",stroke_n['MentalHealth'].median())
print("Mode :",stroke_n['MentalHealth'].mode())
print("Std :",stroke_n['MentalHealth'].std())
# Out:
# Min : 0.0
# Max : 30.0
# Mean : 3.8251593950462426
# Median : 0.0
# Mode : 0    0.0
# Name: MentalHealth, dtype: float64
# Std : 7.856202990216088

# %% [markdown]
# ##### How does difficulty in walking affect stroke

# %%
data[['DiffWalking','Stroke']].value_counts()
# Out:
# DiffWalking  Stroke
# 0            0         268662
# 1            0          39064
# 0            1           6723
# 1            1           5346
# dtype: int64

# %% [markdown]
# Stroke among people having difficulty in walking

# %%
plt.title('Stroke among people having difficulty in walking')
plt.pie([39064,5346],labels=['Didnot get stroke','Got Stroke'],autopct='%.2f')
plt.show()

# %% [markdown]
# Stroke among people not having difficulty in walking

# %%
plt.title('Stroke among people not having difficulty in walking')
plt.pie([268662,6723],labels=['Didnot get stroke','Got Stroke'],autopct='%.2f')
plt.show()

# %%
12.04/2.44
# Out:
# 4.934426229508197

# %% [markdown]
# Chances of getting a stroke is nearly 5 times more in people having difficulty in walking than who donot

# %% [markdown]
# ##### How does sex affect stroke

# %%
data[['Sex','Stroke']].value_counts()
# Out:
# Sex     Stroke
# Female  0         161378
# Male    0         146348
# Female  1           6427
# Male    1           5642
# dtype: int64

# %% [markdown]
# Distribution of Stroke in Females

# %%
plt.title('Stroke among Females')
plt.pie([161378,6427],labels=['Didnot get a Stroke','Got a stroke'],autopct='%.2f')
plt.show()

# %% [markdown]
# Distribution of Stroke among Females

# %%
plt.title('Stroke among Males')
plt.pie([146348,5642],labels=['Didnot get a Stroke','Got a stroke'],autopct='%.2f')
plt.show()

# %% [markdown]
# ##### How does age affect stroke

# %%
under25=data[data['AgeCategory']=='18-24']

# %%
under45 = data[
    (data['AgeCategory'] == '25-29') |
    (data['AgeCategory'] == '30-34') |
    (data['AgeCategory'] == '35-39') |
    (data['AgeCategory'] == '40-44')
]

# %%
under60 = data[
    (data['AgeCategory'] == '45-49') |
    (data['AgeCategory'] == '50-54') |
    (data['AgeCategory'] == '55-59') 
]

# %%
under80 = data[
    (data['AgeCategory'] == '60-64') |
    (data['AgeCategory'] == '64-69') |
    (data['AgeCategory'] == '70-74') |
    (data['AgeCategory'] == '75-79')
]

# %%
above80=data[data['AgeCategory']=='80 or older']

# %%
under25['Stroke'].value_counts()
# Out:
# 0    21003
# 1       61
# Name: Stroke, dtype: int64

# %%
plt.title('Stroke in Under 25 age group')
plt.pie([21003,61],labels=['Didnot get a Stroke','Got a Stroke'],autopct='%.2f')
plt.show()

# %%
under45['Stroke'].value_counts()
# Out:
# 0    76557
# 1      707
# Name: Stroke, dtype: int64

# %%
plt.title('Stroke in Under 45 age group')
plt.pie([76557,707],labels=['Didnot get a Stroke','Got a Stroke'],autopct='%.2f')
plt.show()

# %%
under60['Stroke'].value_counts()
# Out:
# 0    74716
# 1     2214
# Name: Stroke, dtype: int64

# %%
plt.title('Stroke in Under 60 age group')
plt.pie([74716,2214],labels=['Didnot get a Stroke','Got a Stroke'],autopct='%.2f')
plt.show()

# %%
under80['Stroke'].value_counts()
# Out:
# 0    81149
# 1     5084
# Name: Stroke, dtype: int64

# %%
plt.title('Stroke in Under 80 age group')
plt.pie([81149,5084],labels=['Didnot get a Stroke','Got a Stroke'],autopct='%.2f')
plt.show()

# %%
above80['Stroke'].value_counts()
# Out:
# 0    21855
# 1     2298
# Name: Stroke, dtype: int64

# %%
plt.title('Stroke in Above 80 age group')
plt.pie([21855,2298],labels=['Didnot get a Stroke','Got a Stroke'],autopct='%.2f')
plt.show()

# %% [markdown]
# ##### How does race affect stroke

# %%
data[['Race','Stroke']].value_counts()
# Out:
# Race                            Stroke
# White                           0         235928
# Hispanic                        0          26851
# Black                           0          21683
# Other                           0          10452
# White                           1           9284
# Asian                           0           7917
# American Indian/Alaskan Native  0           4895
# Black                           1           1256
# Hispanic                        1            595
# Other                           1            476
# American Indian/Alaskan Native  1            307
# Asian                           1            151
# dtype: int64

# %%
white=data[data['Race'].str.contains('White')]
american_indian=data[data['Race'].str.contains('American Indian/Alaskan Native')]
black=data[data['Race'].str.contains('Black')]
hispanic=data[data['Race'].str.contains('Hispanic')]
asian=data[data['Race'].str.contains('Asian')]
other=data[data['Race'].str.contains('Other')]

# %%
plt.title('Stroke Among Whites')
plt.pie(white['Stroke'].value_counts(),labels=['Didnot get Stroke','Got stroke'],autopct='%.2f')
plt.show()

# %%
plt.title('Stroke Among American Indians/Alaskan Native')
plt.pie(american_indian['Stroke'].value_counts(),labels=['Didnot get Stroke','Got stroke'],autopct='%.2f')
plt.show()

# %%
plt.title('Stroke Among Black')
plt.pie(black['Stroke'].value_counts(),labels=['Didnot get Stroke','Got stroke'],autopct='%.2f')
plt.show()

# %%
plt.title('Stroke Among Hispanic')
plt.pie(hispanic['Stroke'].value_counts(),labels=['Didnot get Stroke','Got stroke'],autopct='%.2f')
plt.show()

# %%
plt.title('Stroke Among Asian')
plt.pie(asian['Stroke'].value_counts(),labels=['Didnot get Stroke','Got stroke'],autopct='%.2f')
plt.show()

# %%
plt.title('Others')
plt.pie(other['Stroke'].value_counts(),labels=['Didnot get Stroke','Got stroke'],autopct='%.2f')
plt.show()

# %% [markdown]
# ##### How does Diabetes Effect Stroke

# %%
data[['Diabetic','Stroke']].value_counts()
# Out:
# Diabetic                 Stroke
# 0                        0         261754
# 1                        0          37058
# 0                        1           7899
# No, borderline diabetes  0           6427
# 1                        1           3744
# Yes (during pregnancy)   0           2487
# No, borderline diabetes  1            354
# Yes (during pregnancy)   1             72
# dtype: int64

# %%
plt.title('Stroke among people without diabetes')
plt.pie([261754,7899],labels=['Didnot get stroke','Got Stroke'],autopct='%.2f')
plt.show()

# %%
plt.title('Stroke among people with borderline diabetes')
plt.pie([6427,354],labels=['Didnot get stroke','Got Stroke'],autopct='%.2f')
plt.show()

# %%
plt.title('Stroke among people with diabetes during Pregnancy')
plt.pie([2487,72],labels=['Didnot get stroke','Got Stroke'],autopct='%.2f')
plt.show()

# %%
plt.title('Stroke among people with diabetes')
plt.pie([37058,3744],labels=['Didnot get stroke','Got Stroke'],autopct='%.2f')
plt.show()

# %% [markdown]
# ##### How does Physical Activity affect stroke

# %%
data[['PhysicalActivity','Stroke']].value_counts()
# Out:
# PhysicalActivity  Stroke
# 1                 0         240620
# 0                 0          67106
# 1                 1           7337
# 0                 1           4732
# dtype: int64

# %%
plt.title('Stroke among people who do Physical Activity')
plt.pie([240620,7337],labels=['Didnot get Stroke','Got Stroke'],autopct='%.2f')
plt.show()

# %%
plt.title('Stroke among people who donot do Physical Activity')
plt.pie([67106,4732],labels=['Didnot get Stroke','Got Stroke'],autopct='%.2f')
plt.show()

# %% [markdown]
# ##### How does General Health affect stroke

# %%
data[['GenHealth','Stroke']].value_counts()
# Out:
# GenHealth  Stroke
# Very good  0         111586
# Good       0          89250
# Excellent  0          66151
# Fair       0          31379
# Poor       0           9360
# Good       1           3879
# Fair       1           3298
# Very good  1           2272
# Poor       1           1929
# Excellent  1            691
# dtype: int64

# %%
plt.title('Stroke among people with Excellent General Health')
plt.pie([66151,691],labels=['Didnot get stroke','Got a stroke'],autopct='%.2f')
plt.show()

# %%
plt.title('Stroke among people with Very Good General Health')
plt.pie([111586,2272],labels=['Didnot get stroke','Got a stroke'],autopct='%.2f')
plt.show()

# %%
plt.title('Stroke among people with Good General Health')
plt.pie([89250,3879],labels=['Didnot get stroke','Got a stroke'],autopct='%.2f')
plt.show()

# %%
plt.title('Stroke among people with Fair General Health')
plt.pie([31379,3298],labels=['Didnot get stroke','Got a stroke'],autopct='%.2f')
plt.show()

# %%
plt.title('Stroke among people with Poor General Health')
plt.pie([9360,1929],labels=['Didnot get stroke','Got a stroke'],autopct='%.2f')
plt.show()

# %% [markdown]
# ##### How does Asthma affect Stroke

# %%
data[['Asthma','Stroke']].value_counts()
# Out:
# Asthma  Stroke
# 0       0         267279
# 1       0          40447
# 0       1           9644
# 1       1           2425
# dtype: int64

# %%
plt.title('Stroke among people having Asthma')
plt.pie([40447,2425],labels=['Didnot get Stroke','Got a stroke'],autopct='%.2f')
plt.show()

# %%
plt.title('Stroke among people not having Asthma')
plt.pie([267279,9644],labels=['Didnot get Stroke','Got a stroke'],autopct='%.2f')
plt.show()

# %% [markdown]
# ##### How does Kidney Disease affect Stroke

# %%
data[['KidneyDisease','Stroke']].value_counts()
# Out:
# KidneyDisease  Stroke
# 0              0         297438
#                1          10578
# 1              0          10288
#                1           1491
# dtype: int64

# %%
plt.title('Stroke among those having Kidney Disease')
plt.pie([10288,1491],labels=['Didnot get Stroke','Got a Stroke'],autopct='%.2f')
plt.show()

# %%
plt.title('Stroke among those having Kidney Disease')
plt.pie([297438,10578],labels=['Didnot get Stroke','Got a Stroke'],autopct='%.2f')
plt.show()

# %% [markdown]
# ##### How does SkinCancer after stroke

# %%
data[['SkinCancer','Stroke']].value_counts()
# Out:
# SkinCancer  Stroke
# 0           0         279885
# 1           0          27841
# 0           1          10091
# 1           1           1978
# dtype: int64

# %%
plt.title('Stroke among those people with Skin Cancer')
plt.pie([27841,1978],labels=['Didnot get a Stroke','Got a Stroke'],autopct='%.2f')
plt.show()

# %%
plt.title('Stroke among those people with Skin Cancer')
plt.pie([279885,10091],labels=['Didnot get a Stroke','Got a Stroke'],autopct='%.2f')
plt.show()

# %% [markdown]
# Insights:
#     1. Heart Disease, Age, Diabetes, Difficulty in Walking,Kidney Disease,General Health effects significantly
#     2. Smoking does affect Stroke but only 2 times higher rate
#     3. Sex doesn't effect much

# %%
|
